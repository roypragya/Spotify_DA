# %% [markdown]
# ### Transformations

# %%
import pandas as pd
tracks_analysis = pd.read_csv("SpotifyAudioFeatures2022.csv")
tracks_analysis.head()
# Out:
#    Unnamed: 0  popularity    artist_name  \
# 0           0          99      Bad Bunny
# 1           1          20      Ish Kevin
# 2           2          84  Calvin Harris
# 3           3           0         Avicii
# 4           4          91     Steve Lacy
#
#                                           track_name                track_id  \
# 0                                    Me Porto Bonito  6Sq7ltF9Qa7SNFBsV5Cogx
# 1                                     My Year (2022)  4eHkG6yWQ4pD0zqVkV0R5a
# 2                Potion (with Dua Lipa & Young Thug)  7fYRg3CEbk6rNCuzNzMT06
# 3  Street Dancer - Sgt Slick's Discotizer 2022 Remix  6m5Pu0B2YVPR8BkrbKvHuE
# 4                                          Bad Habit  5CM4UuQ9Gnd6K2YyKGPMoK
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.911   0.712    1    -5.105     0       0.0817       0.09010
# 1         0.521   0.683    5    -6.240     0       0.5010       0.15900
# 2         0.824   0.697   11    -4.869     0       0.0473       0.15800
# 3         0.658   0.935    2    -6.030     0       0.0679       0.00948
# 4         0.686   0.507    1    -7.097     1       0.0357       0.62600
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000027    0.0933    0.425   92.005       178567               4
# 1          0.000000    0.1870    0.737  139.439       161808               3
# 2          0.000041    0.0770    0.757   99.988       214460               4
# 3          0.670000    0.0536    0.919  124.006       173161               4
# 4          0.000075    0.3830    0.690  168.955       232115               4

# %%
# checking for null values

pd.isnull(tracks_analysis).sum()
# Out:
# Unnamed: 0          0
# popularity          0
# artist_name         0
# track_name          0
# track_id            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
sorted_df=tracks_analysis.sort_values('popularity', ascending=False).head()

# %%
sorted_df
# Out:
#     Unnamed: 0  popularity artist_name                             track_name  \
# 61          61         100    Bizarrap  Quevedo: Bzrp Music Sessions, Vol. 52
# 0            0          99   Bad Bunny                        Me Porto Bonito
# 8            8          97   Bad Bunny                       Tití Me Preguntó
# 35          35          96   Bad Bunny                          Ojitos Lindos
# 10          10          96        Joji                          Glimpse of Us
#
#                   track_id  danceability  energy  key  loudness  mode  \
# 61  2tTmW7RDtMQtBk7m2rYeSw         0.621   0.782    2    -5.548     1
# 0   6Sq7ltF9Qa7SNFBsV5Cogx         0.911   0.712    1    -5.105     0
# 8   1IHWl5LamUGEuP4ozKQSXZ         0.650   0.715    5    -5.198     0
# 35  3k3NWokhRRkEPhCzPmV8TW         0.647   0.686    3    -5.745     0
# 10  6xGruZOHLs39ZbVccQTuPZ         0.440   0.317    8    -9.258     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 61       0.0440        0.0125          0.033000    0.2300    0.550  128.033
# 0        0.0817        0.0901          0.000027    0.0933    0.425   92.005
# 8        0.2530        0.0993          0.000291    0.1260    0.187  106.672
# 35       0.0413        0.0800          0.000001    0.5280    0.268   79.928
# 10       0.0531        0.8910          0.000005    0.1410    0.268  169.914
#
#     duration_ms  time_signature
# 61       198938               4
# 0        178567               4
# 8        243717               4
# 35       258299               4
# 10       233456               3

# %%
# most popular tracks
tracks_analysis.describe()
# Out:
#        Unnamed: 0  popularity  danceability      energy         key  \
# count  950.000000  950.000000    950.000000  950.000000  950.000000
# mean   474.500000   38.393684      0.643218    0.651728    5.118947
# std    274.385677   37.592300      0.167399    0.213554    3.681120
# min      0.000000    0.000000      0.095500    0.010900    0.000000
# 25%    237.250000    0.000000      0.552000    0.507250    1.000000
# 50%    474.500000   15.000000      0.667000    0.673000    5.000000
# 75%    711.750000   76.000000      0.773000    0.817000    8.000000
# max    949.000000  100.000000      0.978000    0.999000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  950.000000  950.000000   950.000000    950.000000        950.000000
# mean    -7.822234    0.607368     0.110930      0.234304          0.154963
# std      4.704014    0.488593     0.116516      0.284295          0.310722
# min    -39.424000    0.000000     0.023100      0.000000          0.000000
# 25%     -9.190500    0.000000     0.039800      0.013725          0.000000
# 50%     -6.528500    1.000000     0.060050      0.096250          0.000022
# 75%     -4.899000    1.000000     0.129750      0.379750          0.041850
# max      1.526000    1.000000     0.910000      0.996000          0.977000
#
#          liveness     valence       tempo   duration_ms  time_signature
# count  950.000000  950.000000  950.000000  9.500000e+02      950.000000
# mean     0.188590    0.517179  124.851718  2.354176e+05        3.921053
# std      0.150707    0.259182   27.649557  2.485507e+05        0.414539
# min      0.021100    0.025400   51.660000  2.000000e+04        1.000000
# 25%      0.094500    0.323250  105.013250  1.684660e+05        4.000000
# 50%      0.125000    0.530000  126.013000  2.011005e+05        4.000000
# 75%      0.249000    0.719750  139.994750  2.549200e+05        4.000000
# max      0.950000    0.981000  203.803000  4.585105e+06        5.000000

# %%
tracks_analysis.set_index("track_name", inplace=True)
tracks_analysis.head()
# Out:
#                                                    Unnamed: 0  popularity  \
# track_name
# Me Porto Bonito                                             0          99
# My Year (2022)                                              1          20
# Potion (with Dua Lipa & Young Thug)                         2          84
# Street Dancer - Sgt Slick's Discotizer 2022 Remix           3           0
# Bad Habit                                                   4          91
#
#                                                      artist_name  \
# track_name
# Me Porto Bonito                                        Bad Bunny
# My Year (2022)                                         Ish Kevin
# Potion (with Dua Lipa & Young Thug)                Calvin Harris
# Street Dancer - Sgt Slick's Discotizer 2022 Remix         Avicii
# Bad Habit                                             Steve Lacy
#
#                                                                  track_id  \
# track_name
# Me Porto Bonito                                    6Sq7ltF9Qa7SNFBsV5Cogx
# My Year (2022)                                     4eHkG6yWQ4pD0zqVkV0R5a
# Potion (with Dua Lipa & Young Thug)                7fYRg3CEbk6rNCuzNzMT06
# Street Dancer - Sgt Slick's Discotizer 2022 Remix  6m5Pu0B2YVPR8BkrbKvHuE
# Bad Habit                                          5CM4UuQ9Gnd6K2YyKGPMoK
#
#                                                    danceability  energy  key  \
# track_name
# Me Porto Bonito                                           0.911   0.712    1
# My Year (2022)                                            0.521   0.683    5
# Potion (with Dua Lipa & Young Thug)                       0.824   0.697   11
# Street Dancer - Sgt Slick's Discotizer 2022 Remix         0.658   0.935    2
# Bad Habit                                                 0.686   0.507    1
#
#                                                    loudness  mode  \
# track_name
# Me Porto Bonito                                      -5.105     0
# My Year (2022)                                       -6.240     0
# Potion (with Dua Lipa & Young Thug)                  -4.869     0
# Street Dancer - Sgt Slick's Discotizer 2022 Remix    -6.030     0
# Bad Habit                                            -7.097     1
#
#                                                    speechiness  acousticness  \
# track_name
# Me Porto Bonito                                         0.0817       0.09010
# My Year (2022)                                          0.5010       0.15900
# Potion (with Dua Lipa & Young Thug)                     0.0473       0.15800
# Street Dancer - Sgt Slick's Discotizer 2022 Remix       0.0679       0.00948
# Bad Habit                                               0.0357       0.62600
#
#                                                    instrumentalness  liveness  \
# track_name
# Me Porto Bonito                                            0.000027    0.0933
# My Year (2022)                                             0.000000    0.1870
# Potion (with Dua Lipa & Young Thug)                        0.000041    0.0770
# Street Dancer - Sgt Slick's Discotizer 2022 Remix          0.670000    0.0536
# Bad Habit                                                  0.000075    0.3830
#
#                                                    valence    tempo  \
# track_name
# Me Porto Bonito                                      0.425   92.005
# My Year (2022)                                       0.737  139.439
# Potion (with Dua Lipa & Young Thug)                  0.757   99.988
# Street Dancer - Sgt Slick's Discotizer 2022 Remix    0.919  124.006
# Bad Habit                                            0.690  168.955
#
#                                                    duration_ms  time_signature
# track_name
# Me Porto Bonito                                         178567               4
# My Year (2022)                                          161808               3
# Potion (with Dua Lipa & Young Thug)                     214460               4
# Street Dancer - Sgt Slick's Discotizer 2022 Remix       173161               4
# Bad Habit                                               232115               4

# %%
tracks_analysis.drop(['Unnamed: 0'], axis=1, inplace=True)
tracks_analysis.head()
# Out:
#                                                    popularity    artist_name  \
# track_name
# Me Porto Bonito                                            99      Bad Bunny
# My Year (2022)                                             20      Ish Kevin
# Potion (with Dua Lipa & Young Thug)                        84  Calvin Harris
# Street Dancer - Sgt Slick's Discotizer 2022 Remix           0         Avicii
# Bad Habit                                                  91     Steve Lacy
#
#                                                                  track_id  \
# track_name
# Me Porto Bonito                                    6Sq7ltF9Qa7SNFBsV5Cogx
# My Year (2022)                                     4eHkG6yWQ4pD0zqVkV0R5a
# Potion (with Dua Lipa & Young Thug)                7fYRg3CEbk6rNCuzNzMT06
# Street Dancer - Sgt Slick's Discotizer 2022 Remix  6m5Pu0B2YVPR8BkrbKvHuE
# Bad Habit                                          5CM4UuQ9Gnd6K2YyKGPMoK
#
#                                                    danceability  energy  key  \
# track_name
# Me Porto Bonito                                           0.911   0.712    1
# My Year (2022)                                            0.521   0.683    5
# Potion (with Dua Lipa & Young Thug)                       0.824   0.697   11
# Street Dancer - Sgt Slick's Discotizer 2022 Remix         0.658   0.935    2
# Bad Habit                                                 0.686   0.507    1
#
#                                                    loudness  mode  \
# track_name
# Me Porto Bonito                                      -5.105     0
# My Year (2022)                                       -6.240     0
# Potion (with Dua Lipa & Young Thug)                  -4.869     0
# Street Dancer - Sgt Slick's Discotizer 2022 Remix    -6.030     0
# Bad Habit                                            -7.097     1
#
#                                                    speechiness  acousticness  \
# track_name
# Me Porto Bonito                                         0.0817       0.09010
# My Year (2022)                                          0.5010       0.15900
# Potion (with Dua Lipa & Young Thug)                     0.0473       0.15800
# Street Dancer - Sgt Slick's Discotizer 2022 Remix       0.0679       0.00948
# Bad Habit                                               0.0357       0.62600
#
#                                                    instrumentalness  liveness  \
# track_name
# Me Porto Bonito                                            0.000027    0.0933
# My Year (2022)                                             0.000000    0.1870
# Potion (with Dua Lipa & Young Thug)                        0.000041    0.0770
# Street Dancer - Sgt Slick's Discotizer 2022 Remix          0.670000    0.0536
# Bad Habit                                                  0.000075    0.3830
#
#                                                    valence    tempo  \
# track_name
# Me Porto Bonito                                      0.425   92.005
# My Year (2022)                                       0.737  139.439
# Potion (with Dua Lipa & Young Thug)                  0.757   99.988
# Street Dancer - Sgt Slick's Discotizer 2022 Remix    0.919  124.006
# Bad Habit                                            0.690  168.955
#
#                                                    duration_ms  time_signature
# track_name
# Me Porto Bonito                                         178567               4
# My Year (2022)                                          161808               3
# Potion (with Dua Lipa & Young Thug)                     214460               4
# Street Dancer - Sgt Slick's Discotizer 2022 Remix       173161               4
# Bad Habit                                               232115               4

# %%
tracks_analysis[["artist_name"]].iloc[32]
# Out:
# artist_name    Swingin' Utters
# Name: Strongman - 2022 Remaster, dtype: object

# %%
tracks_analysis["duration_min"]=tracks_analysis["duration_ms"].apply(lambda x:round((x/1000)/60))
tracks_analysis.drop("duration_ms", inplace=True, axis=1)

# %%
tracks_analysis.duration_min.head()
# Out:
# track_name
# Me Porto Bonito                                      3
# My Year (2022)                                       3
# Potion (with Dua Lipa & Young Thug)                  4
# Street Dancer - Sgt Slick's Discotizer 2022 Remix    3
# Bad Habit                                            4
# Name: duration_min, dtype: int64

# %% [markdown]
# ### Visualisation

# %% [markdown]
# #### Pearson Correlation Method

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (4.37.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (3.5.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn
tracks_analysis.corr()
# Out:
#                   popularity  danceability    energy       key  loudness  \
# popularity          1.000000      0.250295 -0.053401 -0.022604  0.260932
# danceability        0.250295      1.000000  0.140341  0.005729  0.268903
# energy             -0.053401      0.140341  1.000000  0.100783  0.693229
# key                -0.022604      0.005729  0.100783  1.000000  0.082053
# loudness            0.260932      0.268903  0.693229  0.082053  1.000000
# mode                0.078588     -0.075085 -0.108677 -0.185508 -0.079942
# speechiness         0.102242      0.184855  0.012047 -0.043759  0.007418
# acousticness       -0.042582     -0.275069 -0.589200 -0.019057 -0.459746
# instrumentalness   -0.405796     -0.274002 -0.227828  0.013482 -0.478770
# liveness           -0.037241     -0.059173  0.225079  0.007478  0.085020
# valence            -0.024193      0.389625  0.382791  0.079813  0.361675
# tempo              -0.003603     -0.075653  0.145951  0.002937  0.132174
# time_signature      0.000306      0.137339  0.108853  0.026876  0.078238
# duration_min       -0.162878     -0.128694 -0.025534  0.037461 -0.202804
#
#                       mode  speechiness  acousticness  instrumentalness  \
# popularity        0.078588     0.102242     -0.042582         -0.405796
# danceability     -0.075085     0.184855     -0.275069         -0.274002
# energy           -0.108677     0.012047     -0.589200         -0.227828
# key              -0.185508    -0.043759     -0.019057          0.013482
# loudness         -0.079942     0.007418     -0.459746         -0.478770
# mode              1.000000     0.005998      0.091957          0.003603
# speechiness       0.005998     1.000000     -0.065014         -0.215358
# acousticness      0.091957    -0.065014      1.000000          0.245433
# instrumentalness  0.003603    -0.215358      0.245433          1.000000
# liveness         -0.042395     0.101795     -0.076438         -0.055234
# valence          -0.060709    -0.030346     -0.200923         -0.206769
# tempo             0.015998     0.022529     -0.140799         -0.041932
# time_signature    0.070509     0.067281     -0.107630         -0.012644
# duration_min     -0.029095     0.032725      0.017789          0.132845
#
#                   liveness   valence     tempo  time_signature  duration_min
# popularity       -0.037241 -0.024193 -0.003603        0.000306     -0.162878
# danceability     -0.059173  0.389625 -0.075653        0.137339     -0.128694
# energy            0.225079  0.382791  0.145951        0.108853     -0.025534
# key               0.007478  0.079813  0.002937        0.026876      0.037461
# loudness          0.085020  0.361675  0.132174        0.078238     -0.202804
# mode             -0.042395 -0.060709  0.015998        0.070509     -0.029095
# speechiness       0.101795 -0.030346  0.022529        0.067281      0.032725
# acousticness     -0.076438 -0.200923 -0.140799       -0.107630      0.017789
# instrumentalness -0.055234 -0.206769 -0.041932       -0.012644      0.132845
# liveness          1.000000 -0.034616 -0.010109       -0.033273     -0.014286
# valence          -0.034616  1.000000  0.104981        0.098732     -0.108169
# tempo            -0.010109  0.104981  1.000000        0.012751     -0.063419
# time_signature   -0.033273  0.098732  0.012751        1.000000      0.018833
# duration_min     -0.014286 -0.108169 -0.063419        0.018833      1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,14))
seaborn.heatmap(tracks_analysis.corr(), annot=True, cmap="coolwarm").set_title("Pearson Correlation Heatmap using Seaborn")
# Out:
# Text(0.5, 1.0, 'Pearson Correlation Heatmap using Seaborn')

# %%
plt.figure(figsize=(14,14))
seaborn.regplot(data=tracks_analysis, y = "loudness", x="energy", color = "c").set_title("Loudness vs Energy Linear Regression")
# Out:
# Text(0.5, 1.0, 'Loudness vs Energy Linear Regression')

# %%
plt.figure(figsize=(14,14))
seaborn.regplot(data=tracks_analysis, y = "popularity", x="danceability", color = "c").set_title("Popularity vs Danceability Linear Regression")
# Out:
# Text(0.5, 1.0, 'Popularity vs Danceability Linear Regression')

# %%
plt.figure(figsize=(14,14))
seaborn.regplot(data=tracks_analysis, y = "instrumentalness", x="acousticness", color = "c").set_title("Instrumentalness vs Acousticness Linear Regression")
# Out:
# Text(0.5, 1.0, 'Instrumentalness vs Acousticness Linear Regression')
